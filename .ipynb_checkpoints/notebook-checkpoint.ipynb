# %%
# %matplotlib inline
from main import *
import nlp.hebtokenizer as tokenizer
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib as mpl

#default ploting params
mpl.rcParams['font.family'] = 'sans-serif'


#loads the data into a data frame
df = create_posts_df('data/candidates/')
names = df.candidate.unique()

#start posts from the same date
minDate = max([df[df.candidate==name].date.min() for name in df.candidate.unique()])
df = df[df.date>=minDate]

#shuffle the data
df = df.reindex(np.random.permutation(df.index))

df.head(10)
# Out:
#       candidate                date  \
# 936     Bennett 2013-07-28 11:58:08
# 6468      Lapid 2012-05-26 19:10:31
# 2062      Galon 2014-03-20 07:34:45
# 8046  Netanyahu 2012-07-01 15:47:14
# 851     Bennett 2013-10-08 12:39:58
# 2172      Galon 2014-01-22 17:37:22
# 6794      Lapid 2014-11-03 12:29:05
# 1948      Galon 2014-06-19 10:57:30
# 3588      Galon 2014-10-27 19:38:27
# 2309      Galon 2013-10-16 06:03:50
#
#                                                    post
# 936   חוק יסוד משאל עם - עבר בממשלה\n **\nבכל תולדות...
# 6468  ובזמן שהמלגלגים אמרו, "הוא רק בפייסבוק" איפה ה...
# 2062  כמה מביך היה לראות ביומיים האחרונים את שר הביט...
# 8046  להלן סידורי ההלוויה של ראש הממשלה השביעי יצחק ...
# 851   מה הקשר בין מלפפונים בהודו, למעמד מדינת ישראל ...
# 2172  בדרך להצגה "לא בבית ספרנו", שתעלה הערב ב"צוותא...
# 6794  פרויקט "דירה להשכיר" יצא היום לדרך.\nהבוקר הנח...
# 1948  אני יוצאת עכשיו מפגישה עם ראש הממשלה, שעדכן או...
# 3588  כששמעתי את נתניהו אומר הערב בפתיחת מושב הכנסת ...
# 2309  דברים קשים וחריפים מאוד כתב אתמול מבקר המדינה ...

# %%
ax = df.groupby('candidate').count().sort('post',ascending=False).post.plot(kind='barh',alpha=0.8,fontsize=12)
ax.spines["top"].set_visible(False)  
ax.spines["bottom"].set_visible(False)  
ax.spines["right"].set_visible(False)  
ax.set_xlabel('Number of Posts',fontsize=14)
ax.set_ylabel('')
ax.yaxis.grid(False)
ax.xaxis.grid(linestyle='-',linewidth=0.1,which = 'minor',alpha=0.1) 
ax.set_axis_bgcolor('w')

# %%
df['dateStr'] = df.date.apply(lambda x: x.strftime('%Y-%m'))
axs = df.groupby(['candidate','dateStr']).count().post.unstack(level=0).plot(subplots=True)
for ax in axs:
    ax.legend(bbox_to_anchor=(1.42, 1.02))
    ax.set_xlabel('month')
    ax.set_ylim([0,100])
    ax.set_yticklabels([])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.metrics import classification_report
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV
from sklearn.svm import SVC
import hunspell

#an Hebrew spell checker and a stemmer
hspell = hunspell.HunSpell('C:/hunspell/hspell-1.3/he.dic', 'C:/hunspell/hspell-1.3/he.aff')
def my_stemmer(word):
    hstem = hspell.stem(word.encode('utf8'))
    if len(hstem)!=1:
        return word
    else:
        stem = hstem[0].decode('utf8')
        if u'ה'+stem==word:
            return word
        return stem

#define a tokenizer using Yoav Goldbergs' tokenizer http://www.cs.bgu.ac.il/~yoavg/software/hebtokenizer/ and hspell/hunspell stemmer
#skip non words (e.g, punctuations)
def my_tokenizer(sent):
    return [my_stemmer(w) for t,w in tokenizer.tokenize(sent) if t=='HEB' and len(w)>1]


#Hebrew stop words.
STOP_WORDS = set([w.decode('utf8').strip() for w in open('nlp/stopwords.txt','r') if len(w.strip())>0])

#train size is 90% of the data. 10% is left for testing
TRAIN_SIZE = int(0.9 * len(df))
    
#create train and test sets
X = df.post.values
Y = df.candidate.values
X_train = X[:TRAIN_SIZE]
X_test  = X[TRAIN_SIZE:]
Y_train = list(Y[:TRAIN_SIZE])
Y_test  = list(Y[TRAIN_SIZE:])


#run this method to find the best parameters of the mode. you can add other parameters, but it will cost you some time
def find_best_params():
    #create a tfidf vectorizer. we don't have stemmer for hebrew :(
    vectorizer = TfidfVectorizer(stop_words=STOP_WORDS,tokenizer=my_tokenizer)

    #select K best features using chi-squared statistic for each class/feature combination
    ch2 = SelectKBest(chi2)

    #linear SVM training. we will use this classifier as it allows probabilties estimates. you can try other classifiers...
    clf = SVC(kernel='linear')

    #create a pipeline of tfidf transformation, selection of the k best features and the acctual classifier
    pl_clf = Pipeline([('vectorizer', vectorizer),('kbest',ch2),('clf', clf)])

    #different parameters in the pieline that we are going to tune
    parameters = {'vectorizer__ngram_range': [(1,3)],
                  'vectorizer__max_df': [0.3,1.0],
                  'vectorizer__min_df': [2,5],
                  'kbest__k': [6000,'all']}

    #fit the model and find the best parameters using cross validation. this is going to take a while...
    gs_clf = GridSearchCV(pl_clf, parameters)
    gs_clf = gs_clf.fit(X_train, Y_train)

    #print the best parameters values
    best_parameters, score, _ = max(gs_clf.grid_scores_, key=lambda x: x[1])
    for param_name in sorted(parameters.keys()):
        print("%s: %r" % (param_name, best_parameters[param_name]))

# %%
import pickle

#create a new classifier with the best values that we computed above. since kbest value is 'all', we don't need SelectKBest 
vectorizer = TfidfVectorizer(stop_words=STOP_WORDS,tokenizer=my_tokenizer,ngram_range=(1,3),sublinear_tf=True,min_df=2,max_df=1.0)
clf = SVC(kernel='linear',probability=True) #enable probabilities estimates
pl_clf = Pipeline([('vectorizer', vectorizer),('clf', clf)])
pl_clf.fit(X_train,Y_train)

#save the model
pickle.dump(pl_clf,open( "pl_clf.pkl", "w" ))

#evaluation on the test set
predicted = pl_clf.predict(X_test)
print(classification_report(Y_test, predicted))
# Out:
#              precision    recall  f1-score   support
#
#     Bennett       0.89      0.93      0.91       144
#       Galon       0.91      0.91      0.91       138
#      Herzog       0.77      0.86      0.81       107
#       Lapid       0.91      0.62      0.74        52
#   Netanyahu       0.93      0.90      0.92       109
#
# avg / total       0.88      0.88      0.87       550

# %%
import matplotlib.patches as mpatches

#lets predict other people...
def test1():
    dfPoliticians = create_posts_df('data/others/')
    preds = []
    for name in dfPoliticians.candidate.unique():
        pred = pl_clf.predict_proba(dfPoliticians[dfPoliticians.candidate==name].post)
        pred = np.mean(pred,axis=0)
        preds.append(pred)
    tmpDF = pd.DataFrame(preds,columns=clf.classes_,index=dfPoliticians.candidate.unique())
    ax = tmpDF.plot(kind='bar',stacked=True)
    ax.set_ylim([0,1])
    ax.legend(bbox_to_anchor=(1.42, 1.02))   

def test2(): 
    fig, axes = plt.subplots(nrows=3, ncols=4)
    dfPoliticians = create_posts_df('data/others/')
    preds = []
    for name in dfPoliticians.candidate.unique():
        pred = pl_clf.predict_proba(dfPoliticians[dfPoliticians.candidate==name].post)
        pred = np.mean(pred,axis=0)
        preds.append(pred)
    
    i=-1
    maxPred = np.max(preds)
    colors = ['#fbb4ae','#ccebc5','#b3cde3','#decbe4','#fed9a6']
    for name,pred in zip(dfPoliticians.candidate.unique(),preds):
        i+=1
        tmpDF = pd.DataFrame(pred,index=clf.classes_)
        ax = tmpDF.plot(kind='bar',ax=axes[i/4,i % 4],legend=None,sharey=True,color=colors)
        ax.set_title(name,fontsize=9)
        ax.set_ylim([0,maxPred])
        ax.grid(False)
        ax.set_yticks([0, round(maxPred/2,1), round(maxPred,1)])
        ax.get_xaxis().set_visible(False)
        ax.set_axis_bgcolor('w')
        for tick in ax.yaxis.get_major_ticks():
            tick.label.set_fontsize(7) 
        ax.spines["top"].set_visible(False)  
        ax.spines["left"].set_visible(False)  
        ax.spines["right"].set_visible(False) 
       
    patches = []
    for color,name in zip(colors,clf.classes_):
        patches.append(mpatches.Patch(color=color, label=name))
    legend = plt.legend(handles=patches,bbox_to_anchor=(2.4, 4.15))
    frame = legend.get_frame()
    frame.set_facecolor('w')
    for label in legend.get_texts():
        label.set_fontsize(8)

test2()

# %%
#lets find the most important features for each candidatedata:image/png;base64,...
# According to the doc the coef_ are ordered as:
# class 0 vs class 1
# class 0 vs class 2
# ...
# class 0 vs class n-1
# class 1 vs class 2
# class 1 vs class 3
# ...
# ...
# class n-1 vs class n
# we will sum all the weights for each candidate


coefs = clf.coef_.toarray()
candidateWeights = {}
for c in clf.classes_:
    candidateWeights[c] = np.zeros(len(coefs[0]))

coefInd = -1
for i,c1 in enumerate(clf.classes_):
    for j,c2 in enumerate(clf.classes_):
        if j>i:
            coefInd+=1
            candidateWeights[c1] += coefs[coefInd]
            candidateWeights[c2] -= coefs[coefInd]
            
            
for cls,weights in candidateWeights.iteritems():
    print cls
    tups = [(w,f) for f,w in zip(vectorizer.get_feature_names(),weights)]
    tups.sort(reverse=True)
    for w,f in tups[:150]:
        print w,f
    print
# Out:
# Herzog
# 5.15130684262
#  הרצוג
# 5.09780467652 העבודה
# 5.05516134294 מפלגת העבודה
# 4.6668327113 נושא
# 4.21167005295 עת
# 3.92542601922 ביבי
# 3.85587653188 שבת
# 3.77721139106 הערב
# 3.70779726855 לפיד
# 3.49110426962 מוכרחים
# 3.48667158394 מפלגת
# 3.37558477068 הרווחה
# 3.28572933478 מדיני
# 3.23362165914 שבת שלום
# 3.14067230712 על
# 3.13699468701 על מנת
# 3.07735458936 מנת
# 3.05854878745 של
# 2.89191006112 חברי
# 2.80118681139 את
# 2.79314922253 אמש
# 2.77499161781 חברים
# 2.76697997966 ביטחון
# 2.72486465973 אלה
# 2.71051019646 מאחל
# 2.6957772776 עם
# 2.67788884363 הבוקר
# 2.66211151368 מצב
# 2.659640926 המדינה
# 2.62484180863 חברתי
# 2.61620960665 זירה
# 2.57330987624 כולנו
# 2.55846136154 רבין
# 2.47330583131 החוץ
# 2.42440432422 הציוני
# 2.41400428238 ננצח
# 2.41390331171 אלתר
# 2.39443516523 עוני
# 2.39177201828 קשה
# 2.34635753907 חירום
# 2.34394834598 מעבר
# 2.33886579021 ערב
# 2.33688720198 כישלון
# 2.32947756031 דיון
# 2.29226235276 נתניהו לפיד
# 2.27693603278 קשים
# 2.24262502252 מברך
# 2.23562847455 הייתה
# 2.23150148215 התקווה
# 2.21901670911 הכנסת
# 2.19404247534 גזענות
# 2.14955917406 העוני
# 2.14603384488 בכנס
# 2.13031719541 לעיתים
# 2.12757404485 סיעת העבודה
# 2.10123451532 שר
# 2.09291366609 נחליף
# 2.09228057958 ילדי
# 2.08289146183 ראויה
# 2.08103163441 מאבק
# 2.08027991197 הזו
# 2.07985136534 תחת
# 2.07129580285 הנדל"ן
# 2.06638989475 שר החוץ
# 2.06077050003 השדולה
# 2.05897271377 איתו
# 2.05890436193 טובה
# 2.04272211307 המצב
# 2.03256860817 טוב
# 2.03105655526 מוטב
# 2.01944271465 האופוזיציה
# 2.0124429968 מציע
# 2.00913512087 טובות
# 2.0034845623 מיוחד
# 1.99656179477 ציבור
# 1.98989966546 חבר
# 1.98824051903 כדורגל
# 1.96261437479 שבוע
# 1.95447797152 הי
# 1.94861010357 החברתי
# 1.93674530785 משפחות
# 1.92990634752 המפלגה
# 1.91902746661 כשר
# 1.918527354 של נתניהו
# 1.91596365503 פגיעה
# 1.90349377264 יצחק
# 1.88401899122 סיעות
# 1.88135361984 נתניהו
# 1.85319374218 מוזמנים צפות
# 1.84771628559 מנהיגות
# 1.8455051338 דור
# 1.8403056117 ידידי
# 1.82811050967 למען
# 1.82112313771 בו
# 1.81124483866 ב-17 מרץ
# 1.79762161786 דבריו
# 1.77641968866 זירה הבינלאומית
# 1.77421385091 הנורא
# 1.77361241735 המחנה
# 1.77186197425 יחד
# 1.77119453497 מרשים
# 1.77118051989 אני מברך
# 1.76044628614 ב-17
# 1.75671806014 יהי
# 1.73837883647 תנחומיי
# 1.73747042109 בוז'י
# 1.73372410361 מדינית
# 1.71323048105 המציאות
# 1.7095560548 בקר
# 1.70694339674 אייל
# 1.70325013465 ראות את
# 1.70129967156 חברים יקרים
# 1.70025939266 מחנה
# 1.69484355716 שכוח
# 1.68960400459 הסיעה
# 1.68309193741 עד כמה
# 1.67892434425 אני
# 1.67597498507 הזה
# 1.67425767755 בה
# 1.6737803686 מיכל
# 1.66653231899 את ישראל
# 1.66591497075 תהליך
# 1.6514754835 המועצה
# 1.64998719063 אורח
# 1.64957162608 לב
# 1.64786430616 עימות
# 1.64442339756 אנחנו או הוא
# 1.64351910013 של מדינת
# 1.63639692715 שר האוצר
# 1.63493596378 כל הקשור
# 1.63493596378 הקשור
# 1.63329966482 יתכן
# 1.63146940283 מחירי
# 1.63091240281 החברתית
# 1.61794093109 הסדר
# 1.61308953107 של ישראל עולם
# 1.61253303509 סדר
# 1.61214666502 זה אנחנו או
# 1.60458537034 יאיר
# 1.60261417713 אדוני
# 1.59415187557 דברים אמרתי
# 1.59007875329 נורא
# 1.58837807258 איציק
# 1.58465042742 העוסקת
# 1.58369756881 חיים הרצוג
# 1.58296044235 ראיתי
# 1.58286878456 לאומית
# 1.5736544297 המדיני
# 1.57219751254 שלום
# 1.57035589837 ים
#
# Bennett
# 8.01345560159
#  שתפו
# 7.12208636213 אך
# 6.42312569944 עם ישראל
# 6.2807409081 נפתלי
# 5.45875637614 בנט
# 5.3151316362 היהודי
# 5.01666701523 תמונה
# 4.98889141452 עכשיו
# 4.81366318238 הבית היהודי
# 4.75761925887 תודה
# 4.74581382086 אשר
# 4.69424025553 הבית
# 4.51633992136 אחיותיי
# 4.51512850161 אחיי
# 4.4596772077 כאן
# 4.36111043363 יום
# 4.30346518067 דקות
# 4.30100274923 ארץ
# 3.96643916529 רגע
# 3.87277063081 פגשתי
# 3.83852199214 הכלכלה
# 3.78028019042 משרד הכלכלה
# 3.69441876186 אלו
# 3.67046836189 שקד
# 3.53453504829 מחבלים
# 3.48522488826 עוד
# 3.43479982217 וכו
# 3.31737127822 חברת
# 3.26256792747 איילת
# 3.24095121459 פשוט
# 3.23639971018 ישראל
# 3.17645435547 כן
# 3.15063665 אז
# 3.09225326964 שחרור
# 3.05820060571 אנו
# 2.96433853545 רוצחים
# 2.9594870282 חייבים
# 2.95848018946 זה
# 2.95694277447 ראיון
# 2.93671298568 איילת שקד
# 2.92014544033 בית
# 2.8945269716 שומרון
# 2.89245055354 שתפו בנט
# 2.88797072197 העולם
# 2.87379033994 עניין
# 2.86774383213 עת
# 2.86440531388 זהו
# 2.84891186434 הארץ
# 2.80980816557 מספר
# 2.79746875352 תחרות
# 2.79614804137 אחיותיי אחיי
# 2.78727474494 שלום
# 2.75526505584 דתיים
# 2.74152077811 טוב
# 2.73543271818 אורי
# 2.72924381875 הפיצו
# 2.71213778441 מחירים
# 2.6679050564 זה אסף
# 2.64613388644 נקודה
# 2.58844355475 מפקד
# 2.5777009316 אסף
# 2.5526161919 לא
# 2.53000119795 הייטק
# 2.51527569476 אנשי
# 2.51052817583 אנא
# 2.46910544497 תחום
# 2.46812806565 שלום זה אסף
# 2.46647101491 דוד
# 2.46027251257 שלום זה
# 2.45249229858 סין
# 2.44420254827 דרך
# 2.39936742933 סרטון
# 2.38715753541 יון
# 2.3769781686 אהוד ברק
# 2.37477767326 רבבות
# 2.37468226769 לבנון
# 2.36836123111 המחבלים
# 2.35845176733 בוקר
# 2.35801676618 ארץ ישראל
# 2.33277380093 אהוד
# 2.3299856323 בן
# 2.31755543068 אל
# 2.29863722034 משרד
# 2.29706255296 עובדים
# 2.29535194498 בית היהודי
# 2.2871038174 פרשת
# 2.27713651851 עסקים
# 2.26329174711 שבע
# 2.22846686666 אין
# 2.21205446928 לילה טוב
# 2.20223496696 קצת
# 2.19908500013 יהודה
# 2.19870450052 סיימתי
# 2.19214962239 אלינו
# 2.18249896255 אריאל
# 2.1809579234 חברים
# 2.1655006378 מילים
# 2.16361898284 חרדים
# 2.13041995731 השר
# 2.12960199375 אינני
# 2.12923504659 מחבל
# 2.12388673149 יהודי
# 2.11332319375 בלילה
# 2.11239562995 יהודה שומרון
# 2.1048728194 הגולן
# 2.09937503919 שולי
# 2.09757644755 אח
# 2.08922088364 שלום כאן
# 2.08640296521 לוחמי
# 2.08594237927 כלכלה
# 2.07508952835 עובד
# 2.0740525402 הרב
# 2.06652398131 עבודה
# 2.06642237632 ברק
# 2.04696294891 אצל
# 2.03682937765 תוך
# 2.03673180168 טילים
# 2.036545069 ממש
# 2.03047335883 אחי
# 1.99430199017 עד
# 1.98446815952 שקט
# 1.98317867513 חייל
# 1.9764615436 עקיבא
# 1.97533802773 שלג
# 1.96209511395 חדש
# 1.96150169348 חבר'ה
# 1.95928161882 חיי
# 1.94660906144 הגיע
# 1.94449590203 איפה
# 1.94195499405 משהו חדש
# 1.94104150151 שעות
# 1.93827433479 אליי
# 1.92665384155 שלי
# 1.91896925497 לפני מספר
# 1.91676956865 ישראלית
# 1.91520985954 יבין
# 1.9128929808 הרוצחים
# 1.90146108999 עם
# 1.89407343333 נחל
# 1.89039552137 אורבך
# 1.884532393 אוהב
# 1.87851586832 הצלחה
# 1.87450692956 אחיי אחיותיי
# 1.87185691425 תפתח
# 1.87103018042 מנת
# 1.86981002002 אורי אורבך
# 1.86432160977 זבולון
# 1.85264247766 מעל
# 1.85077624407 מה
# 1.85003475173 תורה
#
# Lapid
# 9.07168853624
#  יש עתיד
# 7.37404239724 עתיד
# 4.98221615881 אנחנו
# 4.71919496612 פה
# 4.52724090114 מעמד הביניים
# 4.46695128682 הביניים
# 4.41331735969 מפני
# 4.26450265266 אתם
# 3.97466668067 הישראלי
# 3.80197804667 הם
# 3.79648435712 מעמד
# 3.7402050021 אחרי
# 3.5789918099 שלנו
# 3.53559126698 היות
# 3.51765838966 הזו
# 3.34177347565 הפעם
# 3.34097729391 נטל
# 3.31499183737 שנות
# 3.30742740706 אינו
# 3.30294067547 יש
# 3.29768909508 להם
# 3.28632887973 הביניים הישראלי
# 3.18398214236 ניצולי
# 3.12866867147 כי
# 3.11165187101 מאתנו
# 3.10116505948 בחירות
# 3.09024285103 בלי
# 3.0351419287 אנחנו לא
# 3.02461201928 זוהי
# 3.01691555097 של יש
# 3.00122987372 יותר
# 2.96499827634 ניצולי השואה
# 2.94118359307 באנו
# 2.93384377087 מצרף
# 2.90265224134 של יש עתיד
# 2.89412562091 דיור
# 2.88543557505 מעמד הביניים הישראלי
# 2.87784186041 המצורף
# 2.80213198253 לינק
# 2.78398689822 הלחם
# 2.78199083181 אהיה
# 2.77502666598 וידאו
# 2.75245188201 צריכים
# 2.73455436596 עבוד
# 2.72298574315 היה
# 2.65506481786 היתה
# 2.65200604147 מקום
# 2.62559149008 מישהו
# 2.6023874384 הממשלתיות
# 2.57684810268 היום
# 2.56909596454 הקיר
# 2.55727547086 יוקר המחיה
# 2.54424108814 המחיה
# 2.51729541126 שלהם
# 2.5005296509 דיוק
# 2.48951196813 נתתי
# 2.4478258746 לא
# 2.44719384007 באנו שנות
# 2.44509996302 חינוך
# 2.43539545027 לכם
# 2.43240454947 הגיד
# 2.4182634492 אנגלית
# 2.41764887257 זה
# 2.41256495146 שקלים
# 2.37009536392 טובת
# 2.36913851649 נלחמנו
# 2.3479192795 שביל
# 2.34540338535 את כל
# 2.31463126182 הם היו
# 2.30005997389 שירות שווה כולם
# 2.30005997389 שירות שווה
# 2.30005997389 שווה כולם
# 2.29155957257 אנשים
# 2.28920934586 רק
# 2.27988099675 חי
# 2.26600564008 אבל
# 2.21431532992 השואה
# 2.21030502868 הצגתי
# 2.20987907303 מה
# 2.207981966 וידאו חי
# 2.20626420661 ינואר
# 2.19762200736 השאלות
# 2.18139556817 מותר
# 2.15653188488 יהודים
# 2.14824923003 זכאות
# 2.1358307364 חברות הממשלתיות
# 2.13315721277 השיוויון נטל
# 2.13240730507 המשחק
# 2.13017074555 חושבים
# 2.12003615832 שבה
# 2.11427357738 פירון
# 2.10830455493 שני
# 2.09164170681 אתר שלנו
# 2.0770266678 צמתים
# 2.05835893663 לענות
# 2.0570659973 רמת
# 2.05402572337 השיוויון
# 2.03597715853 מנסה
# 2.02910221376 אתמול
# 2.02088243688 לא יכול
# 2.01253721443 הוספנו
# 2.00101064565 לינק המצורף
# 1.9997973847 צוק איתן
# 1.98856966942 צ'ט
# 1.98371234385 הפלשתינים
# 1.98077943092 אתכם
# 1.97749540149 השני
# 1.97272123884 ביטול
# 1.96835759905 דבר
# 1.96773811012 כל השאלות
# 1.96735340311 את החודש
# 1.94771884944 לנו
# 1.92581529709 שדרות
# 1.91111096358 מיסים
# 1.90972004192 חרדים
# 1.90847854009 חודשים
# 1.90119831781 רחובות
# 1.89569917805 מן
# 1.89231954969 טרור
# 1.88930567642 הישנה
# 1.88783892902 לא מעט
# 1.87495281557 הולכים
# 1.86999987912 לבד
# 1.86943296232 הדיור
# 1.85890181704 כתוב
# 1.85321938721 התוכנית
# 1.8482477016 נסיון
# 1.84604865349 איזורית
# 1.84550007586 אחד
# 1.84193927562 אותו
# 1.84108834482 התשובות
# 1.84022201875 הכי
# 1.81938854429 צעירים
# 1.80866579838 את
# 1.80778181197 מיליארד שקלים
# 1.80463036711 פריפריה
# 1.79517668032 הוא לא
# 1.79218259686 צוק
# 1.78983567734 עולם לא היתה
# 1.78877538859 יד קשה
# 1.78366355493 שרים
# 1.77609427251 שירות
# 1.77349935828 שוב
# 1.76968481074 זה לא
# 1.74749410528 מוזמנים
# 1.74257096735 מנסים
# 1.73593137217 רשימת יש עתיד
# 1.73593137217 רשימת יש
# 1.73428577439 אני מצרף
# 1.72863327496 הישנים
#
# Galon
# 16.9354003996
#  מרצ
# 6.87536406696 של
# 5.57163490933 עכשיו
# 5.33307959622 נשים
# 5.070200342 נתניהו
# 5.06821084233 לא
# 5.02299137065 אבל
# 4.64818762781 שלו
# 4.36565437169 ממשלה
# 3.94790742812 שוויון
# 3.84566523455 של מרצ
# 3.7878302942 ליברמן
# 3.78546355419 גם
# 3.68557113298 התנחלויות
# 3.66991628616 ש"ח
# 3.58814284033 רק
# 3.58628444728 פלסטינים
# 3.52485276431 מזמינה
# 3.49448386389 היא
# 3.47613577991 מי
# 3.46560268333 שטחים
# 3.46180718745 הכיבוש
# 3.44485342327 הוא
# 3.41233259442 מתנחלים
# 3.3983345907 זכויות
# 3.39188347997 מאחלת
# 3.37242188372 דמוקרטיה
# 3.30906357838 חופש
# 3.30895040437 הזאת
# 3.30894454577 אלימות
# 3.27669001584 מדיניות
# 3.25775771172 האלה
# 3.14981256593 המתנחלים
# 3.12034268626 הכספים
# 3.011188657 איך
# 2.98453102899 אין
# 2.89257235273 כדי
# 2.84659766618 הימין
# 2.79088096645 החוק
# 2.78786369902 ועדת
# 2.78753191132 הנה
# 2.77961521784 ממש
# 2.75177160161 שיש
# 2.73892070288 את
# 2.68168817732 לפיד
# 2.66044700581 הפלסטינים
# 2.63799696485 מקום
# 2.62905499737 מיליון ש"ח
# 2.62798378236 שמאל
# 2.61045879061 על
# 2.55641430127 חוק
# 2.5298143864 מוזמנים/ות
# 2.51958127334 אירוע
# 2.48775865056 ממליצה
# 2.45869202034 הנשים
# 2.44701556375 בכנסת
# 2.4260960132 הממשלה
# 2.39225528892 היוזמה
# 2.37142079529 פניתי
# 2.36400369738 מציעה
# 2.3583318842 הסדר
# 2.33709600151 דם
# 2.29938799849 מפלגות
# 2.28710051859 מערכת
# 2.2831918629 קרוא
# 2.26343477902 כל כך
# 2.24888367887 אני מאחלת
# 2.24561561077 טור
# 2.23087253367 שמאלנים
# 2.21452622385 צפות
# 2.2064759416 הבוקר
# 2.19993353107 ועדת הכספים
# 2.19830849472 הכנסת
# 2.19556002878 חירות
# 2.16991017764 ישי
# 2.16365453925 אולי
# 2.15431758369 אתכן/ם
# 2.15318961457 הפנסיה
# 2.15173739036 פוליטי
# 2.13700946908 את יום
# 2.13607549542 ח"כ
# 2.13055655525 הצעת
# 2.12440797004 כסף
# 2.11482047225 הטייקונים
# 2.11212169079 הסכסוך
# 2.1105334076 תקציב
# 2.10725634412 מסתבר
# 2.0889550115 צדק
# 2.08178216295 מיליון
# 2.06357386938 חברות
# 2.05910542909 מוזמנים/ות צפות
# 2.05436930878 האוצר
# 2.05416366897 אני שמחה
# 2.04897013248 הבינלאומי
# 2.04226654349 הצטרף
# 2.04187219442 תקיפה
# 2.03872007528 דמוקרטית
# 2.03018822991 שטייניץ
# 2.02663689422 אני מציעה
# 2.02551104963 ספר
# 2.00001444182 כבר
# 1.99601841804 ממשלת נתניהו
# 1.9945709224 שר
# 1.9939928573 אלא
# 1.98883236078 הפסקת
# 1.98430185721 לא רק
# 1.9770717002 שביל
# 1.9770226707 של נתניהו
# 1.95802126087 סינמטק
# 1.9530395849 ערבים
# 1.95233740284 חושבת
# 1.94634261987 הן
# 1.92323148225 כמה
# 1.92140014782 יודעת
# 1.91271275761 מוזמנות
# 1.88504386699 של ראש
# 1.88405977892 ושל
# 1.88252302919 הגזענות
# 1.8805951669 החליף
# 1.86407390539 כנסת
# 1.85220071879 פרסום
# 1.85131579755 קוראת
# 1.8488661763 תל-אביב
# 1.84656878203 הפליטים
# 1.8435403771 אתי
# 1.83510453388 ציבור
# 1.83043705525 מציאות
# 1.81077928439 ממשלת
# 1.80874253614 הרוגים
# 1.80557554322 הפגנה
# 1.79839953154 מפלגות המרכז
# 1.79418174281 הזכיר
# 1.78748749795 יוסי
# 1.78647273121 מאמינה
# 1.78435301116 של הממשלה
# 1.78403963425 ממש לא
# 1.78148120092 המשטרה
# 1.75138679136 קבע
# 1.74652765575 היות
# 1.74526224245 קרנות
# 1.72733195684 פתרון
# 1.7236376701 סבל
# 1.72148359559 מקווה
# 1.72079056541 הרבנות
# 1.71901487588 תקציב הביטחון
# 1.71578641913 הצעת החוק
# 1.7157432008 קראו
# 1.71460218906 משטרה
# 1.70544261779 שלה
# 1.70417956284 בגלל
#
# Netanyahu
# 7.37075491646
#  צילום
# 5.2980753521 אנו
# 4.79022617495 איראן
# 4.60408906787 אזרחי ישראל
# 4.4218752643 בנימין נתניהו
# 4.36632144296 ראש הממשלה בנימין
# 4.36632144296 הממשלה בנימין נתניהו
# 4.36632144296 הממשלה בנימין
# 4.26477950233 בנימין
# 4.20802570901 ישראל
# 4.13944678603 הליכוד
# 3.97410609214 אזרחי
# 3.92793816973 לע''מ
# 3.66864635823 ביטחון
# 3.64274242031 ע"מ
# 3.38740587165 מדינת ישראל
# 3.36181629461 אני מבקש
# 3.217984277 ראש
# 3.20745097141 הטרור
# 3.17699845286 מדינת
# 3.162776429 נפגשתי
# 3.07311457133 העם
# 3.06903187508 שוחחתי
# 3.00787295908 ראש ממשלת
# 2.99795610064 מבקש
# 2.99763773072 ירושלים
# 2.91497887005 רעייתי
# 2.77510802449 היום עם
# 2.71112451861 שרה
# 2.6937956854 מחל
# 2.62498197779 ראש הממשלה
# 2.52266091903 עמנו
# 2.52102311381 נשק
# 2.46486722994 העם היהודי
# 2.42643738727 צה"ל
# 2.36589369049 המסתננים
# 2.28625877691 האו"ם
# 2.2159247528 אבי אוחיון
# 2.21009945878 אלה
# 2.18502752326 הדבר
# 2.18358191056 רה''מ
# 2.16530380265 אוחיון
# 2.16401108805 להגן
# 2.16287758608 הזאת
# 2.16260522442 מאוד
# 2.1109484739 מביע
# 2.09502540834 אני חושב
# 2.09382461806 אמרתי
# 2.07819114341 נפגשתי היום
# 2.03136011923 רעיית
# 2.00827068016 רעיית ראש
# 2.00493283132 צילום אבי
# 1.99997256066 הממשלה
# 1.99658099777 רצועת עזה
# 1.99658099777 רצועת
# 1.99618526105 נשק גרעיני
# 1.9903093032 הגברת
# 1.98761823159 נפגשתי היום עם
# 1.97186325898 גרעיני
# 1.96710331071 אני מביע
# 1.95203745792 צילום אבי אוחיון
# 1.93307053109 הללו
# 1.93147619101 להגן על
# 1.92778064273 ראשותי
# 1.92739062521 בעוצמה
# 1.91829125696 ובוז'י
# 1.91565923379 אני רוצה
# 1.89242895138 חמאס
# 1.86879467479 צה''ל
# 1.86324563171 ההסתננות
# 1.85966345657 שבת שלום כולם
# 1.84617415125 מסתננים
# 1.84385134749 רפורמות
# 1.82999478324 רעיית ראש הממשלה
# 1.82613339382 נמשיך
# 1.82028098658 מדינתנו
# 1.81914589803 דוגמה
# 1.80227440909 שלום כולם
# 1.77622533503 יציבות
# 1.77072468393 צילום עמוס
# 1.76942815317 ראש ממשלת ישראל
# 1.76580225458 ציפי ובוז'י
# 1.76360805269 של חנוכה
# 1.73875006439 טקס
# 1.73673415208 אבי
# 1.69131590519 ביטחון ישראל
# 1.68504084573 חיילי
# 1.68321571793 ראש ממשלה
# 1.66764908463 אני
# 1.66156122031 ביטחון המדינה
# 1.65134517192 את השלום
# 1.65075842906 הנהגתי
# 1.65020256442 ההבדל
# 1.64772391461 צרפת
# 1.64372077823 תנחומים
# 1.64168684271 חודש
# 1.63433313143 אני אומר
# 1.63156132509 בית ישראל
# 1.62835682058 אמרתי להם
# 1.62318849269 השמיד
# 1.62030282699 נעשה
# 1.61694017557 ציפי בוז
# 1.61353132289 האמריקני
# 1.60661063762 אוחיון לע''מ
# 1.60661063762 אבי אוחיון לע''מ
# 1.59770080849 ממשלת שמאל
# 1.58369255435 רעייתי שרה
# 1.58006566744 לא הייתה
# 1.57429236543 המדיניות שלנו
# 1.57312287883 הוציא
# 1.56928193518 על ביטחון
# 1.5618936362 נוספו
# 1.55531701436 חנוכה
# 1.54519409629 כל בית ישראל
# 1.542914314 קורא
# 1.54047188122 צילום קובי גדעון
# 1.54047188122 צילום קובי
# 1.53670303731 חינוך חינם
# 1.53623265418 השמאל
# 1.5351376198 שבוע טוב
# 1.53189233798 דף הפייסבוק
# 1.52271831858 קובי גדעון
# 1.52010732253 של איראן
# 1.51775496517 השתתפתי היום
# 1.50967879153 אני מגנה
# 1.50839352388 זמן
# 1.50626607366 אבנר
# 1.50491145502 שוחחתי הערב עם
# 1.50491145502 שוחחתי הערב
# 1.49638481095 החמאס
# 1.48070053528 חזקה
# 1.47792847995 המדיניות
# 1.47394147869 חינם
# 1.47233217826 הלוגו
# 1.47074875437 הנשק
# 1.46903167368 לחצו כאן
# 1.46469637121 זאת
# 1.45983944308 הגדר
# 1.45692311541 הממשל
# 1.45494200752 נגב
# 1.45491602062 רבה
# 1.44859656883 השנים
# 1.44840488409 גלעד
# 1.44745136138 מהלך
# 1.44373853845 משבח
# 1.43722698693 צילום עמוס בן
# 1.43554672291 של האו"ם
# 1.43315856324 הפגישה
# 1.43309815342 רה"מ
# 1.4316233672 הליכוד ראשותי

# %%
from IPython.display import Image


#lets create a text for the words cloud : http://www.jasondavies.com/wordcloud/#%2F%2Fwww.jasondavies.com%2Fwordcloud%2Fabout%2F
def creatTextForWordCloud(candidate,maxWords):
    weights = candidateWeights[candidate]
    tups = [(w,f) for f,w in zip(vectorizer.get_feature_names(),weights)]
    tups.sort(reverse=True)
    count = 0
    with open('wordcloud/'+candidate+'_wordcloud.txt', 'w') as outfile:
        for w,f in tups:
            count+=1
            if count==maxWords:
                break
            for _ in range(int(w*w)):
                outfile.write(f.encode('utf8')+'\n')
            
for name in names:
    creatTextForWordCloud(name,200)

# %%
#let's see the data in 2d
from sklearn.decomposition import PCA

numOfPoints = len(df)
pca = PCA(n_components=2)
X_r = vectorizer.transform(df.post.values[:numOfPoints])
X_r = pca.fit_transform(X_r.toarray())
y = df.candidate.values[:numOfPoints]

plt.figure()
for c, name in zip("rgbyk", names):
    plt.scatter(X_r[y == name, 0], X_r[y == name, 1], c=c, label=name,alpha=0.8)
plt.legend(bbox_to_anchor=(1.4, 1))


plt.show()
